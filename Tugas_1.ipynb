# %% [markdown]
# <a href="https://colab.research.google.com/github/jenniferr17/Tugas-1/blob/main/Tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

possible_paths = [
    'health_insurance_claims.csv',
    '/mnt/data/health_insurance_claims.csv'
]

data_path = None
for p in possible_paths:
    if os.path.exists(p):
        data_path = p
        break

if data_path is None:
    raise FileNotFoundError("Could not find 'health_insurance_claims.csv'. Please place it next to this notebook or adjust the path.")

df = pd.read_csv(data_path)
print(f'Loaded shape: {df.shape}')
df.head(10)
# Out:
# Loaded shape: (10000, 7)
#    claim_id   age  gender policy_type diagnosis_code  claim_amount  \
# 0         1  69.0    Male    Standard           D001       9536.85
# 1         2  32.0    Male       Basic           D004      13215.40
# 2         3  89.0  Female     Premium           D004       2053.08
# 3         4  78.0    Male       Basic           D001       6538.17
# 4         5  38.0  Female       Basic           D003       4424.58
# 5         6  41.0    Male    Standard           D005       6214.82
# 6         7  20.0    Male    Standard            NaN       4845.43
# 7         8  39.0    Male    Standard           D003       5391.60
# 8         9  70.0  Female    Standard           D005      10029.57
# 9        10  19.0    Male       Basic           D004       2950.42
#
#   payment_status
# 0        Pending
# 1        Pending
# 2        Pending
# 3           Paid
# 4           Paid
# 5           Paid
# 6           Paid
# 7           Paid
# 8           Paid
# 9           Paid
